# %% [markdown]
# # Programming Assignment 1: How may 311 calls? [Total: 10 points]
#
# **Research Question:** How many and what types of 311 calls were made in DC during 2014?
#
# **Technical Skills:** Practice data cleaning and validation skills, such as fixing names and inspecting missing values.
#
# **Description:** In the spirit of transparency, DC government provides information about its services and functions through its open data portal. One of the types of data that it provides is a list of all requests the city receives from the community (included with this notebook, file name `311_City_Service_Requests_in_2014.csv`).
#
# These requests are wide ranging from potholes, to utility outages, to Christmas tree removal, to illegal dumping reports. DC is divided into 8 geographic units called wards. In this assignment you will be using pandas to explore the data set and to fix entries for the variables `WARD` and `SERVICECODEDESCRIPTION`.
#
# # What to submit
#
# You will work in this notebook, which includes questions that require you to either write code, describe your work in a markdown cell, or both.

# %% [markdown]
# ## Important Warning
#
# * Please ensure that you run the cell below before running any others. This will download all required files and packages, as well as installing the necessary packages to ensure the code runs successfully. If you restart the kernel or your runtime session (in Colab), be sure to rerun this cell before running any others.
# * This assignment recommends using **Google Colab**. If you are using Anaconda Jupyter notebook/lab, please ensure that this notebook is kept in a **new folder**. This is because the following commands will **delete all files with the extensions .csv and .py** before downloading the required files.

# %%
required_files = "https://github.com/mainuddin-rony/inst447-fall2024/raw/main/assignment/Programming/Prog%201/required_files.zip"
! rm -rf tests
! rm -f required_files.zip *.csv *.py
! wget $required_files && unzip -j required_files.zip
! mkdir tests && mv *.py tests
! pip install otter-grader==5.5.0

# %%
# Initialize Otter
import otter
grader = otter.Notebook()

# %%
# DO NOT MODIFY, RUN THE CELL BEFORE YOU CODE
import pandas as pd
import io

# %% [markdown]
# ## Q1 (Manual Grading)
#
# **Points:** 1
#
# **Question:** Using pandas, read the csv file `311_City_Service_Requests_in_2014.csv` and load it into a data frame (name it `df`). Show the first five rows of the data frame.

# %%
## Your code here
...

# %% [markdown]
# ## Q2 (Auto Grading)
#
# **Points** 1
#
# **Question**: Write a function named `col_dist` that accepts a data frame as input and returns a series showing the distribution of values for the `WARD` column.
#
# **Hint**: You can use `value_counts()` method from Pandas.
#
# If everything is alright, you can see a similar result like this:
#
#
# ![Screenshot 2024-09-10 at 1.53.18 AM.png](data:image/png;base64,...)
#
# ⬇️⬇️⬇️ YOUR ANSWER IN THE CELL BELOW ⬇️⬇️⬇️

# %%
def col_dist(df):
...

## Call the function here
col_dist(df) ## df is the data frame you loaded in Q1

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q2")

# %% [markdown]
# ## Q3 (Manual Grading)
#
# **Points:** 1
#
# **Question:** From your previous result, carefully inspect the different values in the `Ward` column.
# * Do you notice any patterns or discrepancies in the way the ward names are recorded? If yes, what are they?
# * Based on your observations, suggest a way to clean the data for consistency.
#
# ⬇️⬇️⬇️ YOUR ANSWER IN CELL BELOW ⬇️⬇️⬇️ (Note: Enter your answer in a separate markdown cell below!)

# %% [markdown]
# ## Q4 (Auto Grading)
#
# **Points** 1
#
# **Question:** Write a function called `clean_ward` that converts `WARD` to a numerical column. Your function should take a single parameter -- the data frame -- and return a new data frame with the same columns, but with the `WARD` column converted to float.
#
# **Hint**: To convert a column to numeric, you can either use the `.astype()` method of the Series object associated with the column or the `pd.to_numeric()` function. Refer to Pandas documentation for more information on how to use them.
#
# If everything is ok, you can see a similar result like this:
#
# ![Screenshot 2024-09-07 at 1.20.14 PM.png](data:image/png;base64,...)

# %%
def clean_ward(df):
...

## Call the function here
## The argument df is the data frame you loaded in Q1
## Assign the return data frame to df again. Remember, it will overwrite the previous data frame
df = clean_ward(df)
## Showing the first five rows
df.head()

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q4")

# %% [markdown]
# ## Q5 (Auto Grading)
#
# **Points** 1
#
# **Question:** How many missing values are there in the `WARD` column? Write a function called `missing_ward` that takes as a parameter the cleaned data frame and returns the number of missing values.
#
# Note that this question is independent of the previous questions and you may attempt it even if you did not get the other functions right.

# %%
def missing_ward(df):
...

## Call the function here
## The argument df is the data frame you got in Q4 or in Q1
missing_ward(df)

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q5")

# %% [markdown]
# ## Q6 (Auto Grading)
#
# **Points** 1
#
# **Question:** How many requests (on average) were there per `WARD`? Which Ward has the most requests? Which has the least requests? Write a function called `ward_stats` that takes as parameter the cleaned data frame and returns a *dictionary* with three entries:
#
# * `avg_reqs` – the average number of requests per ward, rounded to *two decimal digits*;
# * `ward_most` – the ward with the most requests; the value will be a float representing the ward (e.g., `1.0` for `Ward 1`)
# * `ward_least` – the ward with least requests; the value will be a float representing the ward (e.g., `1.0` for `Ward 1`)
#
# Ignore (drop) entries where WARD is missing.

# %%
def ward_stats(df):
...

## Call the function here
## The argument df is the data frame you got in Q4 or Q5 or in Q1
ward_stats(df)

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q6")

# %% [markdown]
# ## Q7 (Auto Grading)
#
# **Points** 1
#
# **Question:** Let's shift our attention to the `SERVICECODEDESCRIPTION` column. We need to examine this column by investigating its values. Upon initial examination, it appears that the values are categorical, but there are some inconsistencies. In order to identify these inconsistencies, we should find the unique values of this column and sort them.
#
# Write a function called `sort_servicecode` that takes a data frame as a parameter and returns a sorted list of unique service codes from the `SERVICECODEDESCRIPTION` column.
#
# **Hint**: You can use `Pandas Series.unique()` and `sorted()` function to accomplish this task.
#
#
# Note that this question is independent of the previous questions and you may attempt it even if you did not get the other functions right.

# %%
def sort_servicecode(df):
...

## Call the function here
## The argument df is the data frame after loading the 311_City_Service_Requests_in_2014.csv
sort_servicecode(df)

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q7")

# %% [markdown]
# ## Q8 (Manual Grading)
#
# **Points** 1
#
# **Question:** Review the values in the `SERVICECODEDESCRIPTION` column from the previous question for any issues and inconsistencies. One example is the discrepancy between *Graffiti Removal - Customer Follow-up* and *Graffiti Removal-Customer Follow-up,* which represent the same service event with slightly different formatting. Identify at least two similar issues and suggest ways to resolve them.
#
# ⬇️⬇️⬇️ YOUR ANSWER IN CELL BELOW ⬇️⬇️⬇️

# %% [markdown]
# ## Q9 (Manual Grading)
#
# **Points** 1
#
# **Question:** Write a function named `clean_servicecode` that accepts a data frame as a parameter and outputs a new data frame with a new column named `CleanedServiceDescription`. The new column should contain the cleaned values from the `SERVICECODEDESCRIPTION` column based on the solutions provided in `Q8`.
#
# Note that this question is independent of the previous questions, and you may attempt it even if you do not get the other functions right.

# %%
def clean_servicecode(df):
...

#Run the following code to see the change in the `SERVICECODEDESCRIPTION` column
df = clean_servicecode(df)
mismatch_mask = df['CleanedServiceDescription'] != df['SERVICECODEDESCRIPTION']
print(df[mismatch_mask][['SERVICECODEDESCRIPTION','CleanedServiceDescription']]) #Print the mismatched values

# %% [markdown]
# ## Q10 (Auto Grading)
#
# **Points** 1
#
# **Question:** What are the top 5 most common types of 311 requests (based on `CleanedServiceDescription`)? Write a function called `most_common_reqs` that takes as parameter a cleaned data frame and returns a dictionary with the top 5 most common requests. Each entry in the *dictionary* should consist of the `CleanedServiceDescription` value (the key) and the associated number of requests (the value).

# %%
def most_common_reqs(df):
...

## Call the function here
## The argument df is the data frame you got after executing Q9
most_common_reqs(df)

# %% [markdown]
# When you're ready run the cell below to get feedback on your answer.

# %%
grader.check("q10")

# %% [markdown]
# ## Submission
#
# Don't forget to run all cells in your notebook and then save it. To save, click on `File`, then select `Save/Save Notebook`. After that, download the notebook by going to `File`, then `Download` (for Anaconda notebook), and choosing `Download .ipynb` (for Colab). Finally, submit the notebook on Gradescope using the link found on ELMS.
